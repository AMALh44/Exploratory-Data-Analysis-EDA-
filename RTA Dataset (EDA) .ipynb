# %% [markdown]
# # Problem statement
# * Goal of dataset is to provide detailed information and insights into circimstances,causes and effect of traffic accident
#
# * The data set has been prepared from manual records of road traffic accident of the year 2017-20.

# %% [markdown]
# **1)Time and Date:**
#
# * Time
# * Day_of_week
#
# **2)Driver Demographics:**
#
# * Age_band_of_driver
#
# * Sex_of_driver
#
# * Educational_level
#
# * Driving_experience
#
# **3)Vehicle Information:**
#
#
# * Type_of_vehicle
#
# * Service_year_of_vehicle
#
# * Defect_of_vehicle
#
# **4)Accident Details:**
#
# * Area_accident_occured
#
# * Road_allignment
#
# * Weather_conditions
#
# * Cause_of_accident
#
# **5)Casualty Information:**
#
# * Number_of_casualties
#
# * Casualty_severity
#
# * Age_band_of_casualty
#
# **6)Severity Information:**
#
# * Accident_severity

# %%
# https://www.kaggle.com/datasets/saurabhshahane/road-traffic-accidents

# %% [markdown]
# # understand the data

# %%
import pandas as pd
df=pd.read_csv('/content/RTA Dataset.csv.zip')
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %% [markdown]
# # Data Visualization

# %%
# How many unique values are present in each column.
for x in df.columns:
  print("nunique",x)
  print(df[x].nunique())
  print(" ")
# Out:
# nunique Time
# 1074
#
# nunique Day_of_week
# 7
#
# nunique Age_band_of_driver
# 5
#
# nunique Sex_of_driver
# 3
#
# nunique Educational_level
# 7
#
# nunique Vehicle_driver_relation
# 4
#
# nunique Driving_experience
# 7
#
# nunique Type_of_vehicle
# 17
#
# nunique Owner_of_vehicle
# 4
#
# nunique Service_year_of_vehicle
# 6
#
# nunique Defect_of_vehicle
# 3
#
# nunique Area_accident_occured
# 14
#
# nunique Lanes_or_Medians
# 7
#
# nunique Road_allignment
# 9
#
# nunique Types_of_Junction
# 8
#
# nunique Road_surface_type
# 5
#
# nunique Road_surface_conditions
# 4
#
# nunique Light_conditions
# 4
#
# nunique Weather_conditions
# 9
#
# nunique Type_of_collision
# 10
#
# nunique Number_of_vehicles_involved
# 6
#
# nunique Number_of_casualties
# 8
#
# nunique Vehicle_movement
# 13
#
# nunique Casualty_class
# 4
#
# nunique Sex_of_casualty
# 3
#
# nunique Age_band_of_casualty
# 6
#
# nunique Casualty_severity
# 4
#
# nunique Work_of_casuality
# 7
#
# nunique Fitness_of_casuality
# 5
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
df = pd.read_csv('/content/RTA Dataset.csv.zip')  # Load your dataset here

# Identify categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Create bar plots for each categorical column
for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    value_counts = df[column].value_counts()
    value_counts.plot(kind='bar', color='skyblue', edgecolor='black')

    # Add labels and title
    plt.title(f"Distribution of {column}", fontsize=16)
    plt.xlabel(column, fontsize=14)
    plt.ylabel("Count", fontsize=14)
    plt.xticks(rotation=90, fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Show the plot
    plt.tight_layout(pad=3.0)
    plt.show()
# Out:
# <ipython-input-160-3822e5b812b2>:24: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(pad=3.0)

# %%
# Replace 'Unknown' with 'Female' in Sex_of_driver column
df['Sex_of_driver'] = df['Sex_of_driver'].replace('Unknown', 'Female')

# %%
# Most of the values are unknown
df.drop(columns=['Service_year_of_vehicle'],inplace=True)

# %%
# # Sex_of_casualty, Age_band_of_casualty, and Casualty_severity  have 'na' values
# df = df.dropna(subset=['Sex_of_casualty'],inplace=True)
# df = df.dropna(subset=['Age_band_of_casualty'],inplace=True)
# df = df.dropna(subset=['Casualty_severity'],inplace=True)

# %% [markdown]
# # Data Cleaning

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# Age_band_of_casualty           object
# ...

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# ...

# %%
# Fill missing values  with the mode
df['Educational_level'].fillna(df['Educational_level'].mode()[0],inplace=True)
df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0],inplace=True)
df['Driving_experience'].fillna(df['Driving_experience'].mode()[0],inplace=True)
df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0],inplace=True)
df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0],inplace=True)
#df['Service_year_of_vehicle'].fillna(df['Service_year_of_vehicle'].mode()[0],inplace=True)
df['Defect_of_vehicle'].fillna(df['Defect_of_vehicle'].mode()[0],inplace=True)
df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0],inplace=True)
df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0],inplace=True)
df['Road_allignment'].fillna(df['Road_allignment'].mode()[0],inplace=True)
df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0],inplace=True)
df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0],inplace=True)
df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0],inplace=True)
df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0],inplace=True)
df['Work_of_casuality'].fillna(df['Work_of_casuality'].mode()[0],inplace=True)
df['Fitness_of_casuality'].fillna(df['Fitness_of_casuality'].mode()[0],inplace=True)
# Out:
# <ipython-input-166-615fde679b0d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Educational_level'].fillna(df['Educational_level'].mode()[0],inplace=True)
# <ipython-input-166-615fde679b0d>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# Fitness_of_casuality           0
# ...

# %% [markdown]
# # Correlation Analysis

# %%
# How many unique values are present in each column.
for x in df.columns:
  print("nunique",x)
  print(df[x].nunique())
  print(" ")
# Out:
# nunique Time
# 1074
#
# nunique Day_of_week
# 7
#
# nunique Age_band_of_driver
# 5
#
# nunique Sex_of_driver
# 2
#
# nunique Educational_level
# 7
#
# nunique Vehicle_driver_relation
# 4
#
# nunique Driving_experience
# 7
#
# nunique Type_of_vehicle
# 17
#
# nunique Owner_of_vehicle
# 4
#
# nunique Defect_of_vehicle
# 3
#
# nunique Area_accident_occured
# 14
#
# nunique Lanes_or_Medians
# 7
#
# nunique Road_allignment
# 9
#
# nunique Types_of_Junction
# 8
#
# nunique Road_surface_type
# 5
#
# nunique Road_surface_conditions
# 4
#
# nunique Light_conditions
# 4
#
# nunique Weather_conditions
# 9
#
# nunique Type_of_collision
# 10
#
# nunique Number_of_vehicles_involved
# 6
#
# nunique Number_of_casualties
# 8
#
# nunique Vehicle_movement
# 13
#
# nunique Casualty_class
# 4
#
# nunique Sex_of_casualty
# 3
#
# nunique Age_band_of_casualty
# 6
#
# nunique Casualty_severity
# 4
#
# nunique Work_of_casuality
# 7
#
# nunique Fitness_of_casuality
# 5
#
# nunique Pedestrian_movement
# 9
#
# ...

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# Age_band_of_casualty           object
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Defect_of_vehicle',
#        'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
#        'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions',
#        'Light_conditions', 'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty',
#        'Age_band_of_casualty', 'Casualty_severity', 'Work_of_casuality',
#        'Fitness_of_casuality', 'Pedestrian_movement', 'Cause_of_accident',
#        'Accident_severity'],
#       dtype='object')

# %%
# Converting all the strings to numerical values using labelencoder class
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
labelencoder = LabelEncoder()

# Apply Label Encoding to each column
df['Time'] = labelencoder.fit_transform(df['Time'])
df['Day_of_week'] = labelencoder.fit_transform(df['Day_of_week'])
df['Age_band_of_driver'] = labelencoder.fit_transform(df['Age_band_of_driver'])
df['Sex_of_driver'] = labelencoder.fit_transform(df['Sex_of_driver'])
df['Educational_level'] = labelencoder.fit_transform(df['Educational_level'])
df['Vehicle_driver_relation'] = labelencoder.fit_transform(df['Vehicle_driver_relation'])
df['Driving_experience'] = labelencoder.fit_transform(df['Driving_experience'])
df['Type_of_vehicle'] = labelencoder.fit_transform(df['Type_of_vehicle'])
df['Owner_of_vehicle'] = labelencoder.fit_transform(df['Owner_of_vehicle'])
df['Defect_of_vehicle'] = labelencoder.fit_transform(df['Defect_of_vehicle'])
df['Area_accident_occured'] = labelencoder.fit_transform(df['Area_accident_occured'])
df['Lanes_or_Medians'] = labelencoder.fit_transform(df['Lanes_or_Medians'])
df['Road_allignment'] = labelencoder.fit_transform(df['Road_allignment'])
df['Types_of_Junction'] = labelencoder.fit_transform(df['Types_of_Junction'])
df['Road_surface_type'] = labelencoder.fit_transform(df['Road_surface_type'])
df['Road_surface_conditions'] = labelencoder.fit_transform(df['Road_surface_conditions'])
df['Light_conditions'] = labelencoder.fit_transform(df['Light_conditions'])
df['Weather_conditions'] = labelencoder.fit_transform(df['Weather_conditions'])
df['Type_of_collision'] = labelencoder.fit_transform(df['Type_of_collision'])
df['Vehicle_movement'] = labelencoder.fit_transform(df['Vehicle_movement'])
df['Casualty_class'] = labelencoder.fit_transform(df['Casualty_class'])
df['Sex_of_casualty'] = labelencoder.fit_transform(df['Sex_of_casualty'])
df['Age_band_of_casualty'] = labelencoder.fit_transform(df['Age_band_of_casualty'])
df['Casualty_severity'] = labelencoder.fit_transform(df['Casualty_severity'])
df['Work_of_casuality'] = labelencoder.fit_transform(df['Work_of_casuality'])
df['Fitness_of_casuality'] = labelencoder.fit_transform(df['Fitness_of_casuality'])
df['Pedestrian_movement'] = labelencoder.fit_transform(df['Pedestrian_movement'])
df['Cause_of_accident'] = labelencoder.fit_transform(df['Cause_of_accident'])
df['Accident_severity'] = labelencoder.fit_transform(df['Accident_severity'])

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Defect_of_vehicle',
#        'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
#        'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions',
#        'Light_conditions', 'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty',
#        'Age_band_of_casualty', 'Casualty_severity', 'Work_of_casuality',
#        'Fitness_of_casuality', 'Pedestrian_movement', 'Cause_of_accident',
#        'Accident_severity'],
#       dtype='object')

# %%
# import pandas as pd
# from sklearn.preprocessing import LabelEncoder


# # Create a LabelEncoder instance
# le = LabelEncoder()

# # Loop through each column in the DataFrame
# for column in df.select_dtypes(include=['object']).columns:
#     df[column] = le.fit_transform(df[column])

# # Print the DataFrame with encoded values
# print(df)

# %%
# Correlation matrix heatmap
import matplotlib.pyplot as plt
import seaborn as sns

correlation_matrix = df.corr()
plt.figure(figsize=(18, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# These columns are no correlation with target variable
df.drop(columns=['Day_of_week','Sex_of_driver','Educational_level', 'Road_surface_type','Road_surface_conditions','Sex_of_casualty','Work_of_casuality', 'Fitness_of_casuality'],inplace=True)

# %% [markdown]
# # Feature Engineering

# %%
# To check the skewness of the columns
df.skew()
# Out:
# Time                            0.344968
# Age_band_of_driver              0.883786
# Vehicle_driver_relation         1.803498
# Driving_experience              0.206972
# Type_of_vehicle                 0.453001
# Owner_of_vehicle               -2.590665
# Defect_of_vehicle             -12.261047
# Area_accident_occured          -0.362975
# Lanes_or_Medians                0.253333
# Road_allignment                -2.512556
# Types_of_Junction               0.086904
# Light_conditions               -1.017746
# Weather_conditions              2.782934
# Type_of_collision              -1.223721
# Number_of_vehicles_involved     1.323454
# Number_of_casualties            2.344769
# Vehicle_movement                2.301150
# Casualty_class                  0.047190
# Age_band_of_casualty           -0.038711
# Casualty_severity              -0.239947
# Pedestrian_movement            -4.083192
# Cause_of_accident               0.054907
# Accident_severity              -2.341867
# ...

# %%
import numpy as np

# Log transformation is used to reduce skewness
df['Vehicle_driver_relation'] = np.log1p(df['Vehicle_driver_relation'])
df['Owner_of_vehicle'] = np.log1p(df['Owner_of_vehicle'])
df['Road_allignment'] = np.log1p(df['Road_allignment'])
df['Weather_conditions'] = np.log1p(df['Weather_conditions'])
df['Type_of_collision'] = np.log1p(df['Type_of_collision'])
df['Number_of_vehicles_involved'] = np.log1p(df['Number_of_vehicles_involved'])
df['Number_of_casualties'] = np.log1p(df['Number_of_casualties'])
df['Vehicle_movement'] = np.log1p(df['Vehicle_movement'])
df['Pedestrian_movement'] = np.log1p(df['Pedestrian_movement'])

# %%
# Histogram
df.hist(edgecolor='black',figsize=(19,10))
plt.suptitle('Histograms of RTA Dataset',fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Outliers

# %%
df.plot(kind='box', subplots=True, layout=(6,4), figsize=(10,10),
color='lightblue')
plt.suptitle('Boxplots of RTA Dataset', fontsize=16)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Time', 'Age_band_of_driver', 'Vehicle_driver_relation',
#        'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
#        'Casualty_severity', 'Pedestrian_movement', 'Cause_of_accident',
#        'Accident_severity'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd

# Calculate Q1 and Q3
Q1 = df['Vehicle_driver_relation'].quantile(0.25)
Q3 = df['Vehicle_driver_relation'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Vehicle_driver_relation'] >= (Q1 - 1.5 * IQR)) & (df['Vehicle_driver_relation'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Calculate Q1 and Q3
Q1 = df['Owner_of_vehicle'].quantile(0.25)
Q3 = df['Owner_of_vehicle'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Owner_of_vehicle'] >= (Q1 - 1.5 * IQR)) & (df['Owner_of_vehicle'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Calculate Q1 and Q3
Q1 = df['Defect_of_vehicle'].quantile(0.25)
Q3 = df['Defect_of_vehicle'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Defect_of_vehicle'] >= (Q1 - 1.5 * IQR)) & (df['Defect_of_vehicle'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Calculate Q1 and Q3
Q1 = df['Area_accident_occured'].quantile(0.25)
Q3 = df['Area_accident_occured'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Area_accident_occured'] >= (Q1 - 1.5 * IQR)) & (df['Area_accident_occured'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Calculate Q1 and Q3
Q1 = df['Road_allignment'].quantile(0.25)
Q3 = df['Road_allignment'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Road_allignment'] >= (Q1 - 1.5 * IQR)) & (df['Road_allignment'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Calculate Q1 and Q3
Q1 = df['Weather_conditions'].quantile(0.25)
Q3 = df['Weather_conditions'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Weather_conditions'] >= (Q1 - 1.5 * IQR)) & (df['Weather_conditions'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Calculate Q1 and Q3
Q1 = df['Type_of_collision'].quantile(0.25)
Q3 = df['Type_of_collision'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Type_of_collision'] >= (Q1 - 1.5 * IQR)) & (df['Type_of_collision'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Calculate Q1 and Q3
Q1 = df['Number_of_vehicles_involved'].quantile(0.25)
Q3 = df['Number_of_vehicles_involved'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Number_of_vehicles_involved'] >= (Q1 - 1.5 * IQR)) & (df['Number_of_vehicles_involved'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Calculate Q1 and Q3
Q1 = df['Number_of_casualties'].quantile(0.25)
Q3 = df['Number_of_casualties'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Number_of_casualties'] >= (Q1 - 1.5 * IQR)) & (df['Number_of_casualties'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Calculate Q1 and Q3
Q1 = df['Vehicle_movement'].quantile(0.25)
Q3 = df['Vehicle_movement'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Vehicle_movement'] >= (Q1 - 1.5 * IQR)) & (df['Vehicle_movement'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Calculate Q1 and Q3
Q1 = df['Casualty_severity'].quantile(0.25)
Q3 = df['Casualty_severity'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Casualty_severity'] >= (Q1 - 1.5 * IQR)) & (df['Casualty_severity'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Calculate Q1 and Q3
Q1 = df['Pedestrian_movement'].quantile(0.25)
Q3 = df['Pedestrian_movement'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
df = df[(df['Pedestrian_movement'] >= (Q1 - 1.5 * IQR)) & (df['Pedestrian_movement'] <= (Q3 + 1.5 * IQR))]


# Optionally, reset the index
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Data Scalling

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# # Standardization (mean = 0, std = 1)
# scaler = StandardScaler()
# df[['Time', 'Age_band_of_driver', 'Vehicle_driver_relation',
#        'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
#        'Casualty_severity', 'Pedestrian_movement', 'Cause_of_accident']] = scaler.fit_transform(df[['Time', 'Age_band_of_driver', 'Vehicle_driver_relation',
#                                                                                                            'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle',
#                                                                                                             'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#                                                                                                             'Road_allignment', 'Types_of_Junction', 'Light_conditions',
#                                                                                                            'Weather_conditions', 'Type_of_collision',
#                                                                                                            'Number_of_vehicles_involved', 'Number_of_casualties',
#                                                                                                           'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
#                                                                                                           'Casualty_severity', 'Pedestrian_movement', 'Cause_of_accident']])

#Normalization (scaling to 0-1 range)
minmax_scaler = MinMaxScaler()
df[['Time', 'Age_band_of_driver', 'Vehicle_driver_relation',
       'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle',
       'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
       'Road_allignment', 'Types_of_Junction', 'Light_conditions',
       'Weather_conditions', 'Type_of_collision',
       'Number_of_vehicles_involved', 'Number_of_casualties',
       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
       'Casualty_severity', 'Pedestrian_movement', 'Cause_of_accident']] = minmax_scaler.fit_transform(df[['Time', 'Age_band_of_driver', 'Vehicle_driver_relation',
                                                                                                           'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle',
                                                                                                            'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
                                                                                                            'Road_allignment', 'Types_of_Junction', 'Light_conditions',
                                                                                                           'Weather_conditions', 'Type_of_collision',
                                                                                                           'Number_of_vehicles_involved', 'Number_of_casualties',
                                                                                                          'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
                                                                                                          'Casualty_severity', 'Pedestrian_movement', 'Cause_of_accident']])

# %% [markdown]
# # Initial Modeling And Hypothesis Testing

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report


# Load dataset
X = df[['Time', 'Age_band_of_driver', 'Vehicle_driver_relation',
       'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle',
       'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
       'Road_allignment', 'Types_of_Junction', 'Light_conditions',
       'Weather_conditions', 'Type_of_collision',
       'Number_of_vehicles_involved', 'Number_of_casualties',
       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
       'Casualty_severity', 'Pedestrian_movement', 'Cause_of_accident']]
y = df['Accident_severity']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Evaluate
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred),'\n')
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8731501057082452
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         8
#            1       0.00      0.00      0.00        52
#            2       0.87      1.00      0.93       413
#
#     accuracy                           0.87       473
#    macro avg       0.29      0.33      0.31       473
# weighted avg       0.76      0.87      0.81       473
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# # Documentation And Reporting

# %%
# Summarize key findings
summary = {
    'Dataset Shape': df.shape,
    'Missing Values': df.isnull().sum().sum(),
    'Correlation with Accident_severity': df.corr()['Accident_severity'].sort_values(ascending=False)
}

print("EDA Summary:")
for key, value in summary.items():
    print(f"{key}: {value}")

# Prepare final dataset for modeling
final_df = df[['Time', 'Age_band_of_driver', 'Vehicle_driver_relation',
       'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle',
       'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
       'Road_allignment', 'Types_of_Junction', 'Light_conditions',
       'Weather_conditions', 'Type_of_collision',
       'Number_of_vehicles_involved', 'Number_of_casualties',
       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
       'Casualty_severity', 'Pedestrian_movement', 'Cause_of_accident']]
# Out:
# EDA Summary:
# Dataset Shape: (1574, 23)
# Missing Values: 0
# Correlation with Accident_severity: Accident_severity              1.000000
# Number_of_casualties           0.017759
# Age_band_of_casualty           0.016738
# Casualty_severity              0.008493
# Cause_of_accident              0.001963
# Age_band_of_driver             0.001591
# Area_accident_occured          0.000852
# Casualty_class                -0.003784
# Driving_experience            -0.009174
# Lanes_or_Medians              -0.013329
# Light_conditions              -0.015015
# Vehicle_movement              -0.018993
# Time                          -0.020357
# Type_of_collision             -0.028786
# Type_of_vehicle               -0.032423
# Types_of_Junction             -0.057967
# Vehicle_driver_relation             NaN
# Owner_of_vehicle                    NaN
# Defect_of_vehicle                   NaN
# Road_allignment                     NaN
# Weather_conditions                  NaN
# ...

# %% [markdown]
# After work this dataset with EDA method it contains 12316 rows and 23 columns.No missing values. it fully cleaned dataset.

# %% [markdown]
# The dataset contains records of road traffic accidents from the years 2017 to 2020, manually collected and preprocessed for analysis. Sensitive information has been excluded, and the dataset is designed to help identify major causes of accidents and their severity through various machine learning classification algorithms.
